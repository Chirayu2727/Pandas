# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\hp\\Downloads\\all_stocks_5yr.csv")
df
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %%
df.head()
# Out:
#          date   open   high    low  close    volume Name
# 0  2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1  2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2  2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3  2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4  2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL

# %%
df.tail()
# Out:
#               date   open   high    low  close   volume Name
# 619035  2018-02-01  76.84  78.27  76.69  77.82  2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78  2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83  2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27  4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86  4534912  ZTS

# %%
#analysing the data
df.describe()
# Out:
#                 open           high            low          close  \
# count  619029.000000  619032.000000  619032.000000  619040.000000
# mean       83.023334      83.778311      82.256096      83.043763
# std        97.378769      98.207519      96.507421      97.389748
# min         1.620000       1.690000       1.500000       1.590000
# 25%        40.220000      40.620000      39.830000      40.245000
# 50%        62.590000      63.150000      62.020000      62.620000
# 75%        94.370000      95.180000      93.540000      94.410000
# max      2044.000000    2067.990000    2035.110000    2049.000000
#
#              volume
# count  6.190400e+05
# mean   4.321823e+06
# std    8.693610e+06
# min    0.000000e+00
# 25%    1.070320e+06
# 50%    2.082094e+06
# 75%    4.284509e+06
# max    6.182376e+08

# %%
#single column statistics
df['close'].min()
# Out:
# 1.59

# %%
df['close'].max()
# Out:
# 2049.0

# %%
df['close'].head(15)
# Out:
# 0     14.75
# 1     14.46
# 2     14.27
# 3     14.66
# 4     13.99
# 5     14.50
# 6     14.26
# 7     13.33
# 8     13.37
# 9     13.57
# 10    13.02
# 11    13.26
# 12    13.41
# 13    13.43
# 14    13.61
# Name: close, dtype: float64

# %%
import matplotlib as mt

# %%
df['close'].plot(figsize=(14, 7), title='S&P Closing Price | 2017 - 2022')
# Out:
# <Axes: title={'center': 'S&P Closing Price | 2017 - 2022'}>

# %%
ax1 = df['close'].plot(figsize=(14, 7), title='S&P Closing Price | 2017 - 2022')

ax2 = ax1.twinx()
df['volume'].plot(ax=ax2, color='red', ylim=[df['volume'].min(), df['volume'].max() * 5])

ax1.figure.legend(["close", "volume"])

# %%
df['volume'].plot(kind='hist')       #history
# Out:
# <Axes: ylabel='Frequency'>

# %%
 df['volume'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %%
df['volume'].plot(kind='box', vert=True)
# Out:
# <Axes: >
